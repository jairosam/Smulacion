# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
clientes = pd.read_excel("Replica_cliente.xlsx",sheet_name="Replica")

# %%
clientes.head()
# Out:
#    Unnamed: 0 clas_oper1 clas_oper2  costo_operacion1  costo_operacion2  \
# 0           0        NaN        NaN        538.672163        763.912490
# 1           1        NaN        NaN        360.983341        975.193599
# 2           2        NaN  Reproceso        492.913671        888.325761
# 3           3        NaN        NaN        419.053120        839.316347
# 4           4        NaN        NaN        413.007199        913.650552
#
#    costo_total_produccion  llega conformidad  prVuelva  vuelve  prReclamo  \
# 0             1302.584653   True          PC  0.844815   False   0.605046
# 1             1336.176940   True          PC  0.891061   False   0.070910
# 2             1381.239432   True         PNC  0.286369    True   0.649958
# 3             1258.369467   True          PC  0.086362   False   0.638142
# 4             1326.657751   True          PC  0.729741   False   0.550256
#
#    Reclama  costo_cliente  costo_proceso  ganancia_proceso
# ...

# %%
clientes.drop(clientes.columns[[0]], axis="columns").fillna("")
# Out:
#     clas_oper1 clas_oper2  costo_operacion1  costo_operacion2  \
# 0                                538.672163        763.912490
# 1                                360.983341        975.193599
# 2               Reproceso        492.913671        888.325761
# 3                                419.053120        839.316347
# 4                                413.007199        913.650552
# ..         ...        ...               ...               ...
# 982                              492.454667        835.586889
# 983                              479.436193        909.140810
# 984                              406.004824        892.495275
# 985                              364.127010        764.463640
# 986                              407.048741        969.960560
#
#      costo_total_produccion  llega conformidad  prVuelva  vuelve  prReclamo  \
# 0               1302.584653   True          PC  0.844815   False   0.605046
# ...

# %%
plt.title("Ganancia vs Costo")
plt.xlabel("Ganancia")
plt.ylabel("Costo")
plt.plot(clientes.ganancia_proceso,clientes.costo_proceso)
# Out:
# <img src="data:image/png;base64,..." width="700">
